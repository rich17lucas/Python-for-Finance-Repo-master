# %%
import pandas as pd

# %%
df = pd.read_csv('/home/rnslucas/Documents/azure_usage_2020-01-24.csv')

# %%
df
# Out:
#      BillingAccountId  BillingAccountName BillingPeriodStartDate  \
# 0                 NaN                 NaN             2019-12-25
# 1                 NaN                 NaN             2019-12-25
# 2                 NaN                 NaN             2019-12-25
# 3                 NaN                 NaN             2019-12-25
# 4                 NaN                 NaN             2019-12-25
# ..                ...                 ...                    ...
# 234               NaN                 NaN             2019-12-25
# 235               NaN                 NaN             2019-12-25
# 236               NaN                 NaN             2019-12-25
# 237               NaN                 NaN             2019-12-25
# 238               NaN                 NaN             2019-12-25
#
#     BillingPeriodEndDate                                   BillingProfileId  \
# 0             2020-01-24  /subscriptions/c3eeaba2-1ca2-4053-84f3-efa1105...
# ...
